# %% [markdown]
# <a href="https://colab.research.google.com/github/summaiyamus/NLP-Tasks/blob/main/FrequencyCountFromDoc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install docx2txt
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for docx2txt: filename=docx2txt-0.8-py3-none-any.whl size=3959 sha256=831b19d143aeb2f04bc0dde8139facbcddd016bf0c88e4074b5c4c612747bc37
#   Stored in directory: /root/.cache/pip/wheels/22/58/cf/093d0a6c3ecfdfc5f6ddd5524043b88e59a9a199cb02352966
# Successfully built docx2txt
# ...

# %%
import os
import sys
from collections import Counter
import re
import matplotlib.pyplot as plt

# Check if the provided file path exists
file_path = '/content/POM1.docx';
if not os.path.exists(file_path):
    print("Error: File not found.")
    sys.exit(1)

# Check if the file has an allowed extension
allowed_extensions = ['.txt', '.doc', '.docx']
file_extension = os.path.splitext(file_path)[1]
if file_extension not in allowed_extensions:
    print("Error: Unsupported file format. Supported formats: .txt, .doc, .docx.")
    sys.exit(1)

# Handle the .txt file case
if file_extension == '.txt':
    with open(file_path, 'r') as fd:
        text = fd.read()
elif file_extension == '.doc':
    # Using python-docx2txt to extract text from .doc files
    from docx2txt import process
    text = process(file_path)  # Extract text from .doc
elif file_extension == '.docx':
    # Using python-docx to extract text from .docx files
    from docx import Document
    doc = Document(file_path)
    text = ' '.join([p.text for p in doc.paragraphs])

# Tokenize the text, handle capitalization and special characters
words = re.findall(r'\w+', text.lower())

# Create a frequency dictionary of words
word_freq = Counter(words)

# Sort items by frequency in descending order
sorted_word_freq = sorted(word_freq.items(), key=lambda x: x[1], reverse=True)

# Print the sorted list of words along with their frequencies
for word, count in sorted_word_freq:

  print(f"{word}\t{count}")

# Separate words and counts for plotting
words, counts = zip(*sorted_word_freq)

# Plot the bar chart
plt.figure(figsize=(12, 6))
plt.bar(words[:20], counts[:20])  # Display the top 20 words and their frequencies
plt.xlabel('Words')
plt.ylabel('Frequency')
plt.title('Top 20 Word Frequencies')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better visibility
plt.show()
# Out:
# the	20
# product	13
# of	12
# and	8
# a	7
# 01	6
# that	6
# products	6
# market	5
# to	5
# saeed	5
# ghani	5
# responses	5
# 134202	4
# s	4
# in	4
# at	4
# from	4
# people	4
# brand	3
# for	3
# through	3
# using	3
# we	3
# bcg	3
# expansion	3
# grid	3
# question	3
# mark	3
# survey	3
# most	3
# skincare	3
# they	3
# disliked	3
# group	2
# is	2
# success	2
# this	2
# analysis	2
# interviews	2
# retail	2
# google	2
# reviews	2
# forms	2
# our	2
# have	2
# categories	2
# development	2
# customers	2
# matric	2
# dogs	2
# consumers	2
# end	2
# like	2
# out	2
# 38	2
# you	2
# are	2
# different	2
# indicated	2
# said	2
# as	2
# principle	1
# marketing	1
# assignment	1
# bscs	1
# 7b	1
# members	1
# summaiya	1
# mustafa	1
# 063	1
# amara	1
# habib	1
# 010	1
# ayesha	1
# jabbar	1
# 016	1
# mehwish	1
# zafar	1
# 080	1
# khadija	1
# sher	1
# alam	1
# khan	1
# 134201	1
# 032	1
# bahria	1
# university	1
# islamabad	1
# computer	1
# science	1
# department	1
# fall	1
# 2023	1
# introduction	1
# ...

# %% [markdown]
# # New Section
